# %%
# UBC residence meal plan (RMP) cost
rmp = 5579.72

# Days in a school year (from September 7, 2021 to April 8, 2022)
days = 213

# Average daily cost of meals with residence meal plan
rmp_daily = round(rmp/days, 2)

# %%
# Restaurant calories per dollar spent:
# Tim Hortons
tim_hortons_meals = ['Crispy Chicken Craveables', 'Roast Beef Craveables', 'Regular Caprese', 
                    'Regular Roast Beef & Cheddar Sub', 'Regular Turkey Bacon Club', 'Regular BLT', 
                    'Regular Ham & Cheddar Sub', 'Spicy Buffalo Chicken Wrap', 'Southwest Chicken Wrap', 
                    'Chicken Bacon Ranch Wrap', 'Chicken Wrap', 'Grilled Cheese Melt', 'Bacon Grilled Cheese Melt',
                    'Turkey Melt', 'Ham Melt', 'Soup', 'Chili']
tim_hortons_costs_menu = {'Crispy Chicken Craveables': 4.49, 
                          'Roast Beef Craveables': 4.49, 
                          'Regular Caprese': 4.99, 
                          'Regular Roast Beef & Cheddar Sub': 6.19, 
                          'Regular Turkey Bacon Club': 6.19, 
                          'Regular BLT': 5.49, 
                          'Regular Ham & Cheddar Sub': 5.39, 
                          'Spicy Buffalo Chicken Wrap': 6.39, 
                          'Southwest Chicken Wrap': 6.39, 
                          'Chicken Bacon Ranch Wrap': 6.39, 
                          'Chicken Wrap': 5.99, 
                          'Grilled Cheese Melt': 4.99, 
                          'Bacon Grilled Cheese Melt': 6.19,
                          'Turkey Melt': 6.19, 
                          'Ham Melt': 6.19, 
                          'Soup': 3.79, 
                          'Chili': 5.29}
# Average calories of all meals
tim_hortons_calories_menu = {'Crispy Chicken Craveables': 404, 
                          'Roast Beef Craveables': 404, 
                          'Regular Caprese': 441, 
                          'Regular Roast Beef & Cheddar Sub': 529, 
                          'Regular Turkey Bacon Club': 517, 
                          'Regular BLT': 457, 
                          'Regular Ham & Cheddar Sub': 478, 
                          'Spicy Buffalo Chicken Wrap': 432, 
                          'Southwest Chicken Wrap': 457, 
                          'Chicken Bacon Ranch Wrap': 527, 
                          'Chicken Wrap': 384,
                         'Grilled Cheese Melt': 491, 
                          'Bacon Grilled Cheese Melt': 589,
                          'Turkey Melt': 540, 
                          'Ham Melt': 636, 
                          'Soup': 104, 
                          'Chili': 311} 
tim_hortons_calories = sum([ tim_hortons_calories_menu[i] for i in  tim_hortons_meals]) / len( tim_hortons_meals)
# Average cost of all meals
tim_hortons_cost = sum([tim_hortons_costs_menu[i] for i in tim_hortons_meals]) / len(tim_hortons_meals)
# Starbucks
# Average calories of all meals
starbucks_meals = ['Chicken Caprese on Ciabatta', 'Chicken Bacon on Brioche', 
                   'Tomato Mozzarella on Focaccia', 'Turkey Provolone & Pesto on Ciabatta', 'Crispy Grilled Chesse']
starbucks_cost_menu = {'Chicken Caprese on Ciabatta': 7.75,
                       'Chicken Bacon on Brioche': 7.75, 
                       'Tomato Mozzarella on Focaccia': 7.25,
                       'Turkey Provolone & Pesto on Ciabatta':7.75,
                       'Crispy Grilled Chesse': 5.75}
starbucks_calories_menu = {'Chicken Caprese on Ciabatta': 500,
                           'Chicken Bacon on Brioche': 600, 
                           'Tomato Mozzarella on Focaccia': 380,
                           'Turkey Provolone & Pesto on Ciabatta':520,
                           'Crispy Grilled Chesse': 450}
starbucks_calories = sum([starbucks_calories_menu[i] for i in starbucks_meals]) / len(starbucks_meals)
# Average cost of all meals
starbucks_cost = sum([starbucks_cost_menu[i] for i in starbucks_meals]) / len(starbucks_meals)
# McDonald's 
mcd_meals = ['Big Mac', 'Quarter Pounder', 'Cheeseburger', 'BLT With Crispy Chicken', 'Chicken and Bacon Wrap',
            'McChicken', 'Filet-O-Fish']
mcd_cost_menu = {'Big Mac':5.69, 
                  'Quarter Pounder':6.69,
                  'Cheeseburger':2.49,
                  'BLT With Crispy Chicken':7.59,
                  'Chicken and Bacon Wrap':6.29,
                  'McChicken':5.69, 
                  'Filet-O-Fish':5.69}
mcd_calories_menu = {'Big Mac':560, 
                  'Quarter Pounder':530,
                  'Cheeseburger':290,
                  'BLT With Crispy Chicken': 690,
                  'Chicken and Bacon Wrap': 460,
                  'McChicken': 480, 
                  'Filet-O-Fish':400}
mcd_calories = sum([ mcd_calories_menu[i] for i in mcd_meals]) / len(mcd_meals)
# Average cost of all meals
mcd_cost = sum([mcd_cost_menu[i] for i in mcd_meals]) / len(mcd_meals)
# Gather (of those with given prices; not by weight)
gather_meals = ['Alumni Burger', 'Classic Grilled Cheese', 'Marinated Portobello Burger',
                'Butter Chicken', 'Butter Tofu', 'Crispy Cauliflower Taco',
                'Hearty Tomato, Cumin & Black Bean Soup', 'Havana Bowl Chicken',
                'Havana Bowl Tofu', 'Fresh Avocado and Ponzu Marinated Tofu Salad', 'Avocado Spinich Pasta']
# Average calories of all meals
gather_calories_menu = {'Alumni Burger': 590,
                        'Classic Grilled Cheese': 570,
                        'Marinated Portobello Burger': 550,
                        'Butter Chicken': 1190,
                        'Butter Tofu': 1170,
                        'Crispy Cauliflower Taco': 270,
                        'Hearty Tomato, Cumin & Black Bean Soup': 310,
                        'Havana Bowl Chicken': 660,
                        'Havana Bowl Tofu': 670,
                        'Fresh Avocado and Ponzu Marinated Tofu Salad': 490,
                        'Avocado Spinich Pasta': 1000}
gather_calories = sum([gather_calories_menu[i] for i in gather_meals]) / len(gather_meals)
# Average cost of all meals
gather_cost_menu = {'Alumni Burger': 8.29,
                    'Classic Grilled Cheese': 7.99,
                    'Marinated Portobello Burger': 8.99,
                    'Butter Chicken': 8.99,
                    'Butter Tofu': 7.99,
                    'Crispy Cauliflower Taco': 2.99,
                    'Hearty Tomato, Cumin & Black Bean Soup': 3.10,
                    'Havana Bowl Chicken': 8.99,
                    'Havana Bowl Tofu': 7.99,
                    'Fresh Avocado and Ponzu Marinated Tofu Salad': 8.99,
                    'Avocado Spinich Pasta': 8.99}
gather_cost = sum([gather_cost_menu[i] for i in gather_meals]) / len(gather_meals)
# Perugia Italian Caffe
perugia_meals = ['Tomato & Mushroom Flatbread', 'Prosciutto Cotto Flatbread', 
                 'Capocolla Flatbread', 'Ratatouille', 'Alla Norma', 
                 'Tuscan Chickpea Pasta', 'Quattro Formaggi', 
                 'Spaghetti & Meatball', 'Chicken Alfredo', 'Prosciutto Cotto']
# Average calories of all meals
perugia_calories_menu = {'Tomato & Mushroom Flatbread': 410,
                         'Prosciutto Cotto Flatbread': 410, 
                         'Capocolla Flatbread': 530, 
                         'Ratatouille': 790, 
                         'Alla Norma': 890, 
                         'Tuscan Chickpea Pasta': 840, 
                         'Quattro Formaggi': 1120, 
                         'Spaghetti & Meatball': 1270, 
                         'Chicken Alfredo': 1160, 
                         'Prosciutto Cotto': 990}
perugia_calories = sum([perugia_calories_menu[i] for i in perugia_meals]) / len(perugia_meals)
# Average cost of all meals
perugia_cost_menu = {'Tomato & Mushroom Flatbread': 8.00,
                     'Prosciutto Cotto Flatbread': 8.00, 
                     'Capocolla Flatbread': 8.00, 
                     'Ratatouille': 8.45, 
                     'Alla Norma': 8.45, 
                     'Tuscan Chickpea Pasta': 8.45, 
                     'Quattro Formaggi': 8.45, 
                     'Spaghetti & Meatball': 7.45, 
                     'Chicken Alfredo': 7.45, 
                     'Prosciutto Cotto': 7.45}
perugia_cost = sum([perugia_cost_menu[i] for i in perugia_meals]) / len(perugia_meals)
# Triple O's 
triple_meals = ['Crispy Fish Burger', 'Dippin Chicken Tenders', 'Bacon Cheddar Burger', 'Chipotle BBQ Bacon Melt',
                'Monty Mushroom', 'Original Burger', 'Original Burger with Cheese', 'Double Double Burger']
# Average calories of all meals
# https://www.nutritionix.com/brand/triple-os/products/59f75055e55ffa3351bd1a98 
triple_calories_menu = {'Crispy Fish Burger': 680,
                        'Dippin Chicken Tenders': 270, 
                        'Bacon Cheddar Burger': 930, 
                        'Chipotle BBQ Bacon Melt': 1040,
                        'Monty Mushroom': 940,
                        'Original Burger': 790,
                        'Original Burger with Cheese': 860,
                        'Double Double Burger': 1220}
triple_calories = sum([triple_calories_menu[i] for i in triple_meals]) / len(triple_meals)
# Average cost of all meals
triple_cost_menu = {'Crispy Fish Burger': 8.49,
                    'Dippin Chicken Tenders': 7.49, 
                    'Bacon Cheddar Burger': 9.29, 
                    'Chipotle BBQ Bacon Melt': 9.29,
                    'Monty Mushroom': 8.79,
                    'Original Burger': 7.15,
                    'Original Burger with Cheese': 8.29,
                    'Double Double Burger': 10.99}
triple_cost = sum([triple_cost_menu[i] for i in triple_meals]) / len(triple_meals)
# A&W Canada
aw_meals = ['Bacon Ranch Chicken Wrap', 'Chicken Strips (3 piece)', 'Spicy Chipotle Chicken Wrap', 
            'Double Chicken Buddy Burger', 'Chicken Buddy Burger', 'Spicy Habanero Chicken Burger', 
            'Chubby Chicken Burger', 'BLT Chicken Burger', 'Cheddar Bacon Uncle Burger', 
            'Beyond Meat Burger', 'Grandpa Burger', 'Papa Burger', 'Mama Burger',
            'Double Mozza Burger', 'Double Buddy Burger', 'Double Teen Burger', 
            'Buddy Burger', 'Teen Burger', 'Mozza Burger',  '2 Chicken Wraps']
# Average calories of all meals
aw_calories_menu = {'Bacon Ranch Chicken Wrap': 342,
                    'Chicken Strips (3 piece)': 300,
                    'Spicy Chipotle Chicken Wrap': 317,
                    'Double Chicken Buddy Burger': 480,
                    'Chicken Buddy Burger': 360,
                    'Spicy Habanero Chicken Burger': 520,
                    'Chubby Chicken Burger': 490,
                    'BLT Chicken Burger': 693,
                    'Cheddar Bacon Uncle Burger': 760,
                    'Beyond Meat Burger': 500,
                    'Grandpa Burger': 760,
                    'Papa Burger': 580,
                    'Mama Burger': 400,
                    'Double Mozza Burger': 800,
                    'Double Buddy Burger': 435,
                    'Double Teen Burger': 680,
                    'Buddy Burger': 334,
                    'Teen Burger': 500,
                    'Mozza Burger': 620,
                    '2 Chicken Wraps': 540}
aw_calories = sum([aw_calories_menu[i] for i in aw_meals]) / len(aw_meals)
# Average cost of all meals
aw_cost_menu = {'Bacon Ranch Chicken Wrap': 3.09,
                'Chicken Strips (3 piece)': 7.25,
                'Spicy Chipotle Chicken Wrap': 3.09,
                'Double Chicken Buddy Burger': 4.15,
                'Chicken Buddy Burger': 3.05,
                'Spicy Habanero Chicken Burger': 7.70,
                'Chubby Chicken Burger': 7.25,
                'BLT Chicken Burger': 8.15,
                'Cheddar Bacon Uncle Burger': 9.85,
                'Beyond Meat Burger': 7.95,
                'Grandpa Burger': 8.55,
                'Papa Burger': 7.05,
                'Mama Burger': 5.55,
                'Double Mozza Burger': 8.95,
                'Double Buddy Burger': 3.55,
                'Double Teen Burger': 8.95,
                'Buddy Burger': 2.55,
                'Teen Burger': 7.45,
                'Mozza Burger': 7.45,
                '2 Chicken Wraps': 5.09}
aw_cost = sum([aw_cost_menu[i] for i in aw_meals]) / len(aw_meals)
# Uncle Fatih’s pizza
# https://delcofoods.com/our-products/tips/dough-math/
# Average calories of all meals  
#assuming that Hawaiian, Veggie, Pepperoni pizza is 250g, Cheese is 200g for a small size pizza  
faiths_meals = ['Hawaiian', 'Pepperoni', 'Cheese', 'Veggie']
faiths_cost_menu = {'Hawaiian': 12.45,
                    'Pepperoni': 10.95,
                    'Cheese': 10.45,
                     'Veggie':11.95 }
faiths_calories_menu = {'Hawaiian':655,
                        'Pepperoni': 683,
                        'Cheese': 578, 
                        'Veggie': 688}
fatihs_calories = sum([faiths_calories_menu[i] for i in faiths_meals]) / len(faiths_meals)
# Average cost of all meals
fatihs_cost = sum([faiths_cost_menu[i] for i in faiths_meals]) / len(faiths_meals)

# List of restaurants
Restaurants = ['Tim Hortons', 'Starbucks', 'McDonalds', 'Gather', 'A&W',
               'Perugia Italian Caffe', 'Uncle Fatihs Pizza', 'Triple Os']

# Dictionary of average calories
calories = {'Tim Hortons': tim_hortons_calories,
            'Starbucks': starbucks_calories,
            'Perugia Italian Caffe': perugia_calories,
            'Uncle Fatihs Pizza': fatihs_calories,
            'McDonalds': mcd_calories,
            'A&W': aw_calories,
            'Triple Os' : triple_calories, 
            'Gather' : gather_calories}
# Dictionary of average cost
cost = {'Tim Hortons': tim_hortons_cost,
        'Starbucks': starbucks_cost,
        'Perugia Italian Caffe': perugia_cost, 
        'Uncle Fatihs Pizza': fatihs_cost, 
        'McDonalds': mcd_cost,
        'A&W': aw_cost,
        'Triple Os' : triple_cost, 
        'Gather' : gather_cost}

# %%
import sys
# !{sys.executable} -m pip install pulp 
import pulp
from pulp import * 
prob = LpProblem('student_diet', LpMaximize)
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.9/site-packages (2.6.0)

# %%
# Restaurant chosen = 1, not chosen = 0
x = LpVariable.dicts("", Restaurants, lowBound = 0, upBound = 1, cat = 'Integer')

# %%
# Objective Function 
prob += lpSum([(calories[r]/cost[r])*x[r] for r in Restaurants]) # maximize total restaurants average calorie intake per cost

# Constraints: 
prob += lpSum([calories[r]*x[r] for r in Restaurants]) >= 1600 # meeting lowerbound of calorie intake requirement
prob += lpSum([calories[r]*x[r] for r in Restaurants]) <= 3200 # not exceeding upperbound of calorie intake requirement
prob += lpSum([cost[r]*x[r] for r in Restaurants]) <= rmp_daily # cost not exceeding that of the UBC RMP
prob += lpSum([x[r] for r in Restaurants]) == 3 # 3 restuarants for 3 meals

print(prob)
# Out:
# student_diet:
# MAXIMIZE
# 82.18994236993763*_A&W + 89.67587034813927*_Gather + 84.97383503613258*_McDonalds + 104.92825951341231*_Perugia_Italian_Caffe + 67.58620689655173*_Starbucks + 81.0375670840787*_Tim_Hortons + 96.44597305818286*_Triple_Os + 56.85589519650655*_Uncle_Fatihs_Pizza + 0.0
# SUBJECT TO
# _C1: 520.55 _A&W + 679.090909091 _Gather + 487.142857143 _McDonalds
#  + 841 _Perugia_Italian_Caffe + 490 _Starbucks + 453 _Tim_Hortons
#  + 841.25 _Triple_Os + 651 _Uncle_Fatihs_Pizza >= 1600
#
# _C2: 520.55 _A&W + 679.090909091 _Gather + 487.142857143 _McDonalds
#  + 841 _Perugia_Italian_Caffe + 490 _Starbucks + 453 _Tim_Hortons
#  + 841.25 _Triple_Os + 651 _Uncle_Fatihs_Pizza <= 3200
#
# _C3: 6.3335 _A&W + 7.57272727273 _Gather + 5.73285714286 _McDonalds
#  + 8.015 _Perugia_Italian_Caffe + 7.25 _Starbucks + 5.59 _Tim_Hortons
#  + 8.7225 _Triple_Os + 11.45 _Uncle_Fatihs_Pizza <= 26.2
#
# _C4: _A&W + _Gather + _McDonalds + _Perugia_Italian_Caffe + _Starbucks
#  + _Tim_Hortons + _Triple_Os + _Uncle_Fatihs_Pizza = 3
#
# VARIABLES
# 0 <= _A&W <= 1 Integer
# 0 <= _Gather <= 1 Integer
# 0 <= _McDonalds <= 1 Integer
# 0 <= _Perugia_Italian_Caffe <= 1 Integer
# 0 <= _Starbucks <= 1 Integer
# 0 <= _Tim_Hortons <= 1 Integer
# 0 <= _Triple_Os <= 1 Integer
# 0 <= _Uncle_Fatihs_Pizza <= 1 Integer

# %%
prob.solve()
print("Status:", LpStatus[prob.status])
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/deefc81616964896b9a383836cba480e-pulp.lp -o /tmp/deefc81616964896b9a383836cba480e-pulp.sol
# Reading problem data from '/tmp/deefc81616964896b9a383836cba480e-pulp.lp'...
# 4 rows, 8 columns, 32 non-zeros
# 8 integer variables, all of which are binary
# 28 lines were read
# GLPK Integer Optimizer, v4.65
# 4 rows, 8 columns, 32 non-zeros
# 8 integer variables, all of which are binary
# Preprocessing...
# 4 rows, 8 columns, 32 non-zeros
# 8 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  8.412e+02  ratio =  8.412e+02
# GM: min|aij| =  8.359e-01  max|aij| =  1.196e+00  ratio =  1.431e+00
# EQ: min|aij| =  6.987e-01  max|aij| =  1.000e+00  ratio =  1.431e+00
# 2N: min|aij| =  4.424e-01  max|aij| =  1.431e+00  ratio =  3.235e+00
# Constructing initial basis...
# Size of triangular part is 4
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 4 rows, 8 columns, 32 non-zeros
#       0: obj =   1.705676856e+02 inf =   3.019e+00 (2)
#       4: obj =   2.233667621e+02 inf =   0.000e+00 (0)
# *    11: obj =   2.910501029e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    11: mip =     not found yet <=              +inf        (1; 0)
# +    11: >>>>>   2.910501029e+02 <=   2.910501029e+02   0.0% (1; 0)
# +    11: mip =   2.910501029e+02 <=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.1 Mb (54572 bytes)
# Writing MIP solution to '/tmp/deefc81616964896b9a383836cba480e-pulp.sol'...
# Status: Optimal

# %%
print("Restaurants:")
for a in prob.variables():
    if a.varValue == 1:
        print(a)
# Out:
# Restaurants:
# _Gather
# _Perugia_Italian_Caffe
# _Triple_Os

# %%
print("Restaurants' average calories:")
print("Gather", ":", calories['Gather'])
print("Perugia Italian Caffe", ":", calories['Perugia Italian Caffe'])
print("Triple O's", ":", calories['Triple Os'])

print("Restaurants' average cost:")
print("Gather", ":", round(cost['Gather']))
print("Perugia Italian Caffe", ":", round(cost['Perugia Italian Caffe']))
print("Triple O's", ":", round(cost['Triple Os'], 2))
        
print("Restaurants' average calories per cost:")
print("Gather", ":", round(calories['Gather']/cost['Gather'], 2))
print("Perugia Italian Caffe", ":", round(calories['Perugia Italian Caffe']/cost['Perugia Italian Caffe'], 2))
print("Triple O's", ":", round(calories['Triple Os']/cost['Triple Os'], 2))

average_cost = round(cost['Perugia Italian Caffe']+cost['Gather']+cost['Triple Os'], 2)
print("Average daily cost for all 3 meals = $", average_cost)

average_calories = round(calories['Perugia Italian Caffe']+calories['Gather']+calories['Triple Os'], 2)
print("Average daily calories for all 3 meals = ", average_calories)

print("Money saved from UBC RMP by average daily cost =", round(rmp_daily - average_cost, 2))
print("Money saved from UBC RMP in total =", round(rmp-days*(rmp_daily - average_cost), 2))
print("Daily calories per daily cost spent =", "$", round(average_calories/average_cost, 2))
# Out:
# Restaurants' average calories:
# Gather : 679.0909090909091
# Perugia Italian Caffe : 841.0
# Triple O's : 841.25
# Restaurants' average cost:
# Gather : 8
# Perugia Italian Caffe : 8
# Triple O's : 8.72
# Restaurants' average calories per cost:
# Gather : 89.68
# Perugia Italian Caffe : 104.93
# Triple O's : 96.45
# Average daily cost for all 3 meals = $ 24.31
# Average daily calories for all 3 meals =  2361.34
# Money saved from UBC RMP by average daily cost = 1.89
# Money saved from UBC RMP in total = 5177.15
# Daily calories per daily cost spent = $ 97.13
