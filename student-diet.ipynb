# %%
# UBC residence meal plan (RMP) cost
rmp = 5579.72

# Days in a school year (from September 7, 2021 to April 8, 2022)
days = 213

# Average daily cost of meals with residence meal plan
rmp_daily = rmp/days

# %%
# Restaurant calories per dollar spent:
# Gather
    gather_meals = ['Alumni Burger', 'Classic Grilled Cheese', 'Marinated Portobello Burger',
                    'Shoyu Chicken Burger', 'Tmrw Crunch Burger', 'Butter Chicken',
                    'Butter Tofu', 'Pulled Pork Taco', 'Crispy Cauliflower Taco',
                    'Hearty Tomato, Cumin & Black Bean Soup', 'Havana Bowl Chicken',
                    'Havana Bowl Tofu', 'Baja goat Cheese Salad', 'Tuscan Sundried Tomato Rotini Salad',
                    'Cobb Salad', 'Fresh Avocado and Ponzu Marinated Tofu Salad',
                    'Bibimbap Bowl', 'Classic Tomato Basil Penne', 'Avocado Spinich Pasta']
    # Average calories of all meals
    gather_calories_menu = {'Alumni Burger': 590,
                            'Classic Grilled Cheese': 570,
                            'Marinated Portobello Burger': 550,
                            'Shoyu Chicken Burger': 520,
                            'Tmrw Crunch Burger': 770,
                            'Butter Chicken': 1190,
                            'Butter Tofu': 1170,
                            'Pulled Pork Taco': 290,
                            'Crispy Cauliflower Taco': 270,
                            'Hearty Tomato, Cumin & Black Bean Soup': ,310
                            'Havana Bowl Chicken': 660,
                            'Havana Bowl Tofu': 670,
                            'Baja goat Cheese Salad': 800,
                            'Tuscan Sundried Tomato Rotini Salad': 920,
                            'Cobb Salad': 400,
                            'Fresh Avocado and Ponzu Marinated Tofu Salad': 490,
                            'Bibimbap Bowl': 1050,
                            'Classic Tomato Basil Penne': 780,
                            'Avocado Spinich Pasta': 1000}
    gather_calories = sum([gather_calories_menu(i) for i in gather_meals]) / len(gather_meals)
    # Average cost of all meals
    gather_cost_menu = {'Alumni Burger': 8.29,
                        'Classic Grilled Cheese': 7.99,
                        'Marinated Portobello Burger': 8.99,
                        'Shoyu Chicken Burger': ,
                        'Tmrw Crunch Burger': ,
                        'Butter Chicken': 8.99,
                        'Butter Tofu': 7.99,
                        'Pulled Pork Taco': ,
                        'Crispy Cauliflower Taco': 2.99,
                        'Hearty Tomato, Cumin & Black Bean Soup': 3.10,
                        'Havana Bowl Chicken': 8.99,
                        'Havana Bowl Tofu': 7.99,
                        'Baja goat Cheese Salad': ,
                        'Tuscan Sundried Tomato Rotini Salad': ,
                        'Cobb Salad': ,
                        'Fresh Avocado and Ponzu Marinated Tofu Salad': 8.99,
                        'Bibimbap Bowl': ,
                        'Classic Tomato Basil Penne': ,
                        'Avocado Spinich Pasta': 8.99}
    gather_cost = sum([gather_cost_menu(i) for i in gather_meals]) / len(gather_meals)
# Yunshang Rice Noodle House
    yunshang_meals = []
    # Average calories of all meals
    yunshang_calories_menu = {}
    yunshang_calories = sum([yunshang_calories_menu(i) for i in yunshang_meals]) / len(yunshang_meals)
    # Average cost of all meals
    yunshang_cost_menu = {}
    yunshang_cost = sum([yunshang_cost_menu(i) for i in yunshang_meals]) / len(yunshang_meals)
# Feast
    feast_meals = ['Classic Burger', 'Cheese Burger', 'Classic Veggie Burger',
                   'Classic Chicken Burger', 'Classic Grilled Cheese', 'Classic Poutine',
                   'Pesto Pollo', 'Alla Salsiccia', 'Margherita',
                   'Honey Sesame Chicken Salad', 'Spicy Caesar Salad', 'Ensalada Mexicana',
                   'Egg Salad Sandwich', 'White Bean Burrito', 'Pulled Pork Burrito',
                   'Ancho Chicken Burrito', 'White Bean Burrito Bowl', 'Pulled Pork Burrito Bowl',
                   'Ancho Chicken Burrito Bowl', 'Poblano Relleno', 'Jalapeno Cornbread']
    # Average calories of all meals
    feast_calories_menu = {'Classic Burger': 580,
                           'Cheese Burger': 640,
                           'Classic Veggie Burger': 580,
                           'Classic Chicken Burger': 670,
                           'Classic Grilled Cheese': 860,
                           'Classic Poutine': 880,
                           'Pesto Pollo': 890,
                           'Alla Salsiccia': 700,
                           'Margherita': 690,
                           'Honey Sesame Chicken Salad': 910,
                           'Spicy Caesar Salad': 580,
                           'Ensalada Mexicana': 620,
                           'Egg Salad Sandwich': 630,
                           'White Bean Burrito': 910,
                           'Pulled Pork Burrito': 940,
                           'Ancho Chicken Burrito': 1020,
                           'White Bean Burrito Bowl': 910,
                           'Pulled Pork Burrito Bowl': 670,
                           'Ancho Chicken Burrito Bowl': 750,
                           'Poblano Relleno': 710,
                           'Jalapeno Cornbread': 340}
    feast_calories = sum([feast_calories_menu(i) for i in feast_meals]) / len(feast_meals)
    # Average cost of all meals
    feast_cost_menu = {'Classic Burger': ,
                       'Cheese Burger': ,
                       'Classic Veggie Burger': ,
                       'Classic Chicken Burger': ,
                       'Classic Grilled Cheese': ,
                       'Classic Poutine': ,
                       'Pesto Pollo': ,
                       'Alla Salsiccia': ,
                       'Margherita': ,
                       'Honey Sesame Chicken Salad': ,
                       'Spicy Caesar Salad': ,
                       'Ensalada Mexicana': ,
                       'Egg Salad Sandwich': ,
                       'White Bean Burrito': ,
                       'Pulled Pork Burrito': ,
                       'Ancho Chicken Burrito': ,
                       'White Bean Burrito Bowl': ,
                       'Pulled Pork Burrito Bowl': ,
                       'Ancho Chicken Burrito Bowl': ,
                       'Poblano Relleno': ,
                       'Jalapeno Cornbread': }
    feast_cost = sum([feast_cost_menu(i) for i in feast_meals]) / len(feast_meals)
# The Point 
    point_meals = ['Wings', 'Dry Ribs', 'Breaded Pickles', 'Avocado Toast', 'Queso Dip', 
                   'Poutine', 'Caesar Salad', 'Fall Greens Salad', 'Perogies', 
                   'Clam Vongole', 'Steak Bowl', 'Falafel Bowl', 'Point Burger', 
                   'Steak Sandwich', 'Crispy Chicken Wrap', 'Canadian Burger', 
                   'Salmon Burger', 'Veggie Burger']
    # Average calories of all meals
    point_calories_menu = {'Wings': , 
                           'Dry Ribs': , 
                           'Breaded Pickles': , 
                           'Avocado Toast': , 
                           'Queso Dip'; , 
                           'Poutine': , 
                           'Caesar Salad': , 
                           'Fall Greens Salad': , 
                           'Perogies': , 
                           'Clam Vongole': , 
                           'Steak Bowl': , 
                           'Falafel Bowl': , 
                           'Point Burger': , 
                           'Steak Sandwich': , 
                           'Crispy Chicken Wrap': , 
                           'Canadian Burger': , 
                           'Salmon Burger': , 
                           'Veggie Burger': }
    point_calories = sum([point_calories_menu(i) for i in point_meals]) / len(point_meals)
    # Average cost of all meals
    point_cost_menu = {'Wings': , 
                       'Dry Ribs': , 
                       'Breaded Pickles': , 
                       'Avocado Toast': , 
                       'Queso Dip'; , 
                       'Poutine': , 
                       'Caesar Salad': , 
                       'Fall Greens Salad': , 
                       'Perogies': , 
                       'Clam Vongole': , 
                       'Steak Bowl': , 
                       'Falafel Bowl': , 
                       'Point Burger': , 
                       'Steak Sandwich': , 
                       'Crispy Chicken Wrap': , 
                       'Canadian Burger': , 
                       'Salmon Burger': , 
                       'Veggie Burger': }
    point_cost = sum([point_cost_menu(i) for i in point_meals]) / len(point_meals)
# Open Kitchen
    open_meals = ['Classic Beef Burger', 'Classic Cheese Burger', 'Lentil Mushroom Burger',
                  'Classic Grilled Cheese', 'Poutine', 'Kale Caesar', 'Bandit Salad',
                  'California Chicken Burger', 'Grilled Cheese & Tomato',
                  'Mushroom Pesto Flatbread', 'BBQ Chicken Flatbread', 'Southwest Bowl',
                  'Bibimbap', 'Falafel Bowl', 'Loaded Sweet Potato', 'Jambalaya',
                  'Tofu Jambalaya', 'Westcoast Spaghetti', 'Boneless Beef Short Rib',
                  'Mushroom Ravioli',  'Vegetable Burrito Bowl',  'Chicken Burrito',
                  'Pulled Pork Burrito']
    # Average calories of all meals
    open_calories_menu = {'Classic Beef Burger': 570, 
                          'Classic Cheese Burger': 630,
                          'Lentil Mushroom Burger': 610,
                          'Classic Grilled Cheese': 900,
                          'Poutine': 880,
                          'Kale Caesar': 400,
                          'Bandit Salad': 380,
                          'California Chicken Burger': 820,
                          'Grilled Cheese & Tomato': 1050,
                          'Mushroom Pesto Flatbread': 670,
                          'BBQ Chicken Flatbread': 600,
                          'Southwest Bowl': 880,
                          'Bibimbap': 1060,
                          'Falafel Bowl': 920,
                          'Loaded Sweet Potato': 900,
                          'Jambalaya': 310,
                          'Tofu Jambalaya': 300,
                          'Westcoast Spaghetti': 800,
                          'Boneless Beef Short Rib': 480,
                          'Mushroom Ravioli': 810, 
                          'Vegetable Burrito Bowl': 420, 
                          'Chicken Burrito': 700,
                          'Pulled Pork Burrito': 710}
    open_calories = sum([open_calories_menu(i) for i in open_meals]) / len(open_meals)
    # Average cost of all meals
    open_cost_menu = {'Classic Beef Burger': , 
                      'Classic Cheese Burger': ,
                      'Lentil Mushroom Burger': ,
                      'Classic Grilled Cheese': ,
                      'Poutine': ,
                      'Kale Caesar': ,
                      'Bandit Salad': ,
                      'California Chicken Burger': ,
                      'Grilled Cheese & Tomato': ,
                      'Mushroom Pesto Flatbread': ,
                      'BBQ Chicken Flatbread': ,
                      'Southwest Bowl': ,
                      'Bibimbap': ,
                      'Falafel Bowl': ,
                      'Loaded Sweet Potato': ,
                      'Jambalaya': ,
                      'Tofu Jambalaya': ,
                      'Westcoast Spaghetti': ,
                      'Boneless Beef Short Rib': ,
                      'Mushroom Ravioli': , 
                      'Vegetable Burrito Bowl': , 
                      'Chicken Burrito': ,
                      'Pulled Pork Burrito': }
    open_cost = sum([open_cost_menu(i) for i in open_meals]) / len(open_meals)
# Sesame 
    sesame_meals = []
    # Average calories of all meals
    sesame_calories_menu = {}
    sesame_calories = sum([sesame_calories_menu(i) for i in sesame_meals]) / len(sesame_meals)
    # Average cost of all meals
    sesame_cost_menu = {}
    sesame_cost = sum([sesame_cost_menu(i) for i in sesame_meals]) / len(sesame_meals)
# Brown’s Crafthouse UBC 
    browns_meals = []
    # Average calories of all meals
    browns_calories_menu = {}
    browns_calories = sum([browns_calories_menu(i) for i in browns_meals]) / len(browns_meals)
    # Average cost of all meals
    browns_cost_menu = {}
    browns_cost = sum([browns_cost_menu(i) for i in browns_meals]) / len(browns_meals)
# Downlow Chicken 
    downlow_meals = []
    # Average calories of all meals
    downlow_calories_menu = {}
    downlow_calories = sum([downlow_calories_menu(i) for i in downlow_meals]) / len(downlow_meals)
    # Average cost of all meals
    downlow_cost_menu = {}
    downlow_cost = sum([downlow_cost_menu(i) for i in downlow_meals]) / len(downlow_meals)
# Uncle Fatih’s pizza
    fatihs_meals = []
    # Average calories of all meals
    fatihs_calories_menu = {}
    fatihs_calories = sum([fatihs_calories_menu(i) for i in fatihs_meals]) / len(fatihs_meals)
    # Average cost of all meals
    fatihs_cost_menu = {}
    fatihs_cost = sum([fatihs_cost_menu(i) for i in fatihs_meals]) / len(fatihs_meals)
# Nori Bento & Udon 
    nori_meals = []
    # Average calories of all meals
    nori_calories_menu = {}
    nori_calories = sum([nori_calories_menu(i) for i in nori_meals]) / len(nori_meals)
    # Average cost of all meals
    nori_cost_menu = {}
    nori_cost = sum([nori_cost_menu(i) for i in nori_meals]) / len(nori_meals)
# Jamjar Canteen 
    jamjar_meals = []
    # Average calories of all meals
    jamjar_calories_menu = {}
    jamjar_calories = sum([jamjar_calories_menu(i) for i in jamjar_meals]) / len(jamjar_meals)
    # Average cost of all meals
    jamjar_cost_menu = {}
    jamjar_cost = sum([jamjar_cost_menu(i) for i in jamjar_meals]) / len(jamjar_meals)
# Tacomio UBC
    tacomio_meals = []
    # Average calories of all meals
    tacomio_calories_menu = {}
    tacomio_calories = sum([tacomio_calories_menu(i) for i in tacomio_meals]) / len(tacomio_meals)
    # Average cost of all meals
    tacomio_cost_menu = {}
    tacomio_cost = sum([tacomio_cost_menu(i) for i in tacomio_meals]) / len(tacomio_meals)
# Steve’s Poke Bar
    steve_meals = []
    # Average calories of all meals
    steve_calories_menu = {}
    steve_calories = sum([steves_calories_menu(i) for i in steves_meals]) / len(steves_meals)
    # Average cost of all meals
    steve_cost_menu = {}
    steves_cost = sum([steves_cost_menu(i) for i in steves_meals]) / len(steves_meals)
# Ryuu Japanese Kitchen 
    ryuu_meals = []
    # Average calories of all meals
    ryuu_calories_menu = {}
    ryuu_calories = sum([ryuu_calories_menu(i) for i in ryuu_meals]) / len(ryuu_meals)
    # Average cost of all meals
    ryuu_cost_menu = {}
    ryuu_cost = sum([ryuu_cost_menu(i) for i in ryuu_meals]) / len(ryuu_meals)
# Pizza Garden 
    pizza_garden_meals = []
    # Average calories of all meals
    pizza_garden_calories_menu = {}
    pizza_garden_calories = sum([pizza_garden_calories_menu(i) for i in pizza_garden_meals]) / len(pizza_garden_meals)
    # Average cost of all meals
    pizza_garden_cost_menu = {}
    pizza_garden_cost = sum([pizza_garden_cost_menu(i) for i in pizza_garden_meals]) / len(pizza_garden_meals)
# Kokoro 
    kokoro_meals = []
    # Average calories of all meals
    kokoro_calories_menu = {}
    kokoro_calories = sum([kokoro_calories_menu(i) for i in kokoro_meals]) / len(kokoro_meals)
    # Average cost of all meals
    kokoro_cost_menu = {}
    kokoro_cost = sum([kokoro_cost_menu(i) for i in kokoro_meals]) / len(kokoro_meals)
# Triple O's 
    triple_meals = ['Crispy Fish Burger', 'BC Chicken Burger', 'Spicy Ultimate Crunch Burger', 
                    'Dippin Chicken Tenders', 'Bacon Cheddar Burger', 'Chipotle BBQ Bacon Melt',
                    'Monty Mushroom', 'Original Burger', 'Original Burger with Cheese', 'Double Double Burger']
    # Average calories of all meals
    triple_calories_menu = {'Crispy Fish Burger': ,
                            'BC Chicken Burger': , 
                            'Spicy Ultimate Crunch Burger': , 
                            'Dippin Chicken Tenders': , 
                            'Bacon Cheddar Burger': , 
                            'Chipotle BBQ Bacon Melt': ,
                            'Monty Mushroom': ,
                            'Original Burger': ,
                            'Original Burger with Cheese': ,
                            'Double Double Burger': }
    triple_calories = sum([triple_calories_menu(i) for i in triple_meals]) / len(triple_meals)
    # Average cost of all meals
    triple_cost_menu = {'Crispy Fish Burger': 8.49,
                        'BC Chicken Burger': 10.49, 
                        'Spicy Ultimate Crunch Burger': 8.49, 
                        'Dippin Chicken Tenders': 7.49, 
                        'Bacon Cheddar Burger': 9.29, 
                        'Chipotle BBQ Bacon Melt': 9.29,
                        'Monty Mushroom': 8.79,
                        'Original Burger': 7.15,
                        'Original Burger with Cheese': 8.29,
                        'Double Double Burger': 10.99}
    triple_cost = sum([triple_cost_menu(i) for i in triple_meals]) / len(triple_meals)
# A&W Canada
    aw_meals = ['Bacon Ranch Chicken Wrap', 'Chicken Strips (3 piece)', 'Spicy Chipotle Chicken Wrap', 
                'Double Chicken Buddy Burger', 'Chicken Buddy Burger', 'Spicy Habanero Chicken Burger', 
                'Chubby Chicken Burger', 'BLT Chicken Burger', 'Cheddar Bacon Uncle Burger', 
                'Beyond Meat Burger', 'Grandpa Burger', 'Papa Burger', 'Mama Burger',
                'Double Mozza Burger', 'Double Buddy Burger', 'Double Teen Burger', 
                'Buddy Burger', 'Teen Burger', 'Mozza Burger',  '2 Chicken Wraps']
    # Average calories of all meals
    aw_calories_menu = {'Bacon Ranch Chicken Wrap': 342,
                        'Chicken Strips (3 piece)': 300,
                        'Spicy Chipotle Chicken Wrap': 317,
                        'Double Chicken Buddy Burger': 480,
                        'Chicken Buddy Burger': 360,
                        'Spicy Habanero Chicken Burger': 520,
                        'Chubby Chicken Burger': 490,
                        'BLT Chicken Burger': 693,
                        'Cheddar Bacon Uncle Burger': 760,
                        'Beyond Meat Burger': 500,
                        'Grandpa Burger': 760,
                        'Papa Burger': 580,
                        'Mama Burger': 400,
                        'Double Mozza Burger': 800,
                        'Double Buddy Burger': 435,
                        'Double Teen Burger': 680,
                        'Buddy Burger': 334,
                        'Teen Burger': 500,
                        'Mozza Burger': 620,
                        '2 Chicken Wraps': 540}
    aw_calories = sum([aw_calories_menu(i) for i in aw_meals]) / len(aw_meals)
    # Average cost of all meals
    aw_cost_menu = {'Bacon Ranch Chicken Wrap': 3.09,
                    'Chicken Strips (3 piece)': 7.25,
                    'Spicy Chipotle Chicken Wrap': 3.09,
                    'Double Chicken Buddy Burger': 4.15,
                    'Chicken Buddy Burger': 3.05,
                    'Spicy Habanero Chicken Burger': 7.70,
                    'Chubby Chicken Burger': 7.25,
                    'BLT Chicken Burger': 8.15,
                    'Cheddar Bacon Uncle Burger': 9.85,
                    'Beyond Meat Burger': 7.95,
                    'Grandpa Burger': 8.55,
                    'Papa Burger': 7.05,
                    'Mama Burger': 5.55,
                    'Double Mozza Burger': 8.95,
                    'Double Buddy Burger': 3.55,
                    'Double Teen Burger': 8.95,
                    'Buddy Burger': 2.55,
                    'Teen Burger': 7.45,
                    'Mozza Burger': 7.45,
                    '2 Chicken Wraps': 5.09}
    aw_cost = sum([aw_cost_menu(i) for i in aw_meals]) / len(aw_meals)
    
# List of restaurants
Restaruants = ['Mercante', 'Tim Hortons', 'Starbucks', 'The Point', 'Kinton Ramen', 
               'Sesame', 'Browns Crafthouse', 'Downlow chicken', 'Uncle Fatihs Pizza', 
               'Nori Bento & Udon', 'Jamjar Canteen', 'Tacomio UBC', 'Steves Poke Bar', 
               'Ryuu Japanese Kitchen', 'Pizza Garden', 'Kokoro', 'A&W',
               'Yunshang Rice Noodle', 'Triple Os', 'Open Kitchen', 'Feast' , 'Gather']

# Dictionary of average calories
calories = {'Mercante': mercante_calories,
            'Tim Hortons': tims_calories,
            'Starbucks': starbucks_calories,
            'The Point': point_calories,
            'Kinton Ramen': kinton_calories, 
            'Sesame': sesame_calories, 
            'Browns Crafthouse': browns_calories, 
            'Downlow chicken': downlow_calories, 
            'Uncle Fatihs Pizza': faiths_calories, 
            'Nori Bento & Udon': nori_calories, 
            'Jamjar Canteen': jamjar_calories,
            'Tacomio UBC': tacomio_calories,
            'Steves Poke Bar': steves_calories,
            'Ryuu Japanese Kitchen': ryuu_calories,
            'Pizza Garden': pizza_garden_calories,
            'Kokoro': kokoro_calories,
            'A&W': aw_calories
            'Yunshang Rice Noodle' = yunshang_calories, 
            'Triple Os' = triple_calories, 
            'Open Kitchen' = open_calories, 
            'Feast' = feast_calories,
            'Gather' = gather_calories}
# Dictionary of average cost
cost = {'Mercante': mercante_cost,
        'Tim Hortons': tims_cost,
        'Starbucks': starbucks_cost,
        'The Point': point_cost,
        'Kinton Ramen': kinton_cost, 
        'Sesame': sesame_cost, 
        'Browns Crafthouse': browns_cost, 
        'Downlow chicken': downlow_cost, 
        'Uncle Fatihs Pizza': faiths_cost, 
        'Nori Bento & Udon': nori_cost, 
        'Jamjar Canteen': jamjar_cost,
        'Tacomio UBC': tacomio_cost,
        'Steves Poke Bar': steves_cost,
        'Ryuu Japanese Kitchen': ryuu_cost,
        'Pizza Garden': pizza_garden_cost,
        'Kokoro': kokoro_cost,
        'A&W': aw_cost
        'Yunshang Rice Noodle' = yunshang_cost, 
        'Triple Os' = triple_cost, 
        'Open Kitchen' = open_cost, 
        'Feast' = feast_cost,
        'Gather' = gather_cost}

# %%
import sys
# !{sys.executable} -m pip install pulp 
import pulp
from pulp import * 
prob = LpProblem('student_diet', LpMaximize)

# %%
# Restaurant chosen = 1, not chosen = 0
x = LpVariable.dicts("visit", Restaurants, lowBound = 0, upBound = 1, cat = 'Integer')

# %%
# Objective Function 
prob += lpSum([(calorie[r]/cost[r])*x[r] for r in Restaurants]) # maximize total restaurants average calorie intake per cost

# Constraints: 
prob += lpSum([calorie[r]*x[r] for r in Restaurants]) >= 1600 # meeting lowerbound of calorie intake requirement
prob += lpSum([calorie[r]*x[r] for r in Restaurants]) <= 3200 # not exceeding upperbound of calorie intake requirement
prob += lpSum([cost[r]*x[r] for r in Restaurants]) <= rmp_daily # cost not exceeding that of the UBC RMP
prob += lpSum([x[r] for r in Restaurants]) == 3 # 3 restuarants for 3 meals

print(prob)

# %%
prob.solve()
print("Status:", LpStatus[prob.status])

# %%
print("Restaurants:")
for a in prob.variables():
    if a.varValue == 1:
        print(a)

print("Restaurants' average calories:")
for a in prob.variables():
    if a.varValue == 1:
        print(a, ":", calories[a])

print("Restaurants' average cost:")
for a in prob.variables():
    if a.varValue == 1:
        print(a, ": $", round(cost[a], 2))
        
print("Restaurants' average calories per cost:")
for a in prob.variables():
    if a.varValue == 1:
        print(a, ":", calories[a]/cost[a])

daily_cost = 0;
for a in prob.variables():
    if a.varValue == 1:
        daily_cost += cost[a]
print("Average daily cost for all 3 meals = $", round(daily_cost, 2))

daily_calories = 0;
for a in prob.variables():
    if a.varValue == 1:
        daily_calories += calories[a]
print("Average daily calories for all 3 meals = $", daily_calories)

print("Money saved from UBC RMP by average daily cost =", round(rmp_daily - daily_cost, 2))
print("Daily calories per daily cost spent =", "$", round(daily_calories/daily_cost, 2))
